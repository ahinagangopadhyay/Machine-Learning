# %%
# Run this only once
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#   Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
# Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Rolling back uninstall of numpy
#   Moving to c:\users\ahina\anaconda3\lib\site-packages\numpy-1.26.4.dist-info\
#    from C:\Users\AHINA\anaconda3\Lib\site-packages\~umpy-1.26.4.dist-info
#   Moving to c:\users\ahina\anaconda3\lib\site-packages\numpy\__config__.py
#    from C:\Users\AHINA\AppData\Local\Temp\pip-uninstall-yhq98hf9\__config__.py
#   Moving to c:\users\ahina\anaconda3\lib\site-packages\numpy\__init__.cython-30.pxd
#    from C:\Users\AHINA\AppData\Local\Temp\pip-uninstall-yhq98hf9\__init__.cython-30.pxd
#   Moving to c:\users\ahina\anaconda3\lib\site-packages\numpy\__init__.pxd
#    from C:\Users\AHINA\AppData\Local\Temp\pip-uninstall-yhq98hf9\__init__.pxd
# ...

# %%
import pandas as pd
import re
import spacy
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
nlp = spacy.load("en_core_web_sm")
stop_words = spacy.lang.en.stop_words.STOP_WORDS

# %%
# Sample balanced dataset
data = {
    "text": [
        "I love this movie, it was fantastic!",
        "Terrible plot and bad acting.",
        "Absolutely wonderful film. Loved every moment.",
        "Worst movie ever. Waste of time.",
        "Great story and excellent direction.",
        "Awful acting and poor script.",
    ] * 334,  # Multiplied to simulate 1000+1000 samples
    "label": ["positive", "negative", "positive", "negative", "positive", "negative"] * 334
}
df = pd.DataFrame(data)

# %%
# Out:
# label
# neg    1000
# pos    1000
# Name: count, dtype: int64

# %%
# Out:
# This movie was absolutely brilliant! I loved every second of it.
